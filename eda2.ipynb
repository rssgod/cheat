# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("employee_data.csv")

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender Department   Job_Role  Monthly_Income  \
# 0            1   58  Female         IT    Manager          154.88
# 1            2   48  Female      Sales  Assistant          130.79
# 2            3   34    Male  Marketing  Assistant          137.44
# 3            4   27  Female  Marketing    Manager          680.90
# 4            5   40    Male  Marketing  Executive          102.06
#
#    Years_at_Company  Performance_Rating  Project_Count  \
# 0                15                   4              6
# 1                 6                   1              2
# 2                24                   1              6
# 3                10                   4              9
# 4                29                   1              3
#
#    No. of Companies Worked
# 0                        3
# 1                        2
# 2                        3
# 3                        3
# 4                        3

# %%
df.tail()
# Out:
#     Employee_ID  Age  Gender Department   Job_Role  Monthly_Income  \
# 95           96   28    Male         HR    Analyst          710.30
# 96           97   27  Female         IT  Assistant          507.60
# 97           98   31  Female  Marketing  Assistant          599.40
# 98           99   53  Female  Marketing  Executive          674.40
# 99          100   52    Male         IT    Analyst          174.66
#
#     Years_at_Company  Performance_Rating  Project_Count  \
# 95                 7                   2              4
# 96                 6                   4              7
# 97                22                   3              9
# 98                23                   3              5
# 99                 3                   1              2
#
#     No. of Companies Worked
# 95                        2
# 96                        3
# 97                        2
# 98                        3
# 99                        4

# %%
df.describe()
# Out:
#        Employee_ID         Age  Monthly_Income  Years_at_Company  \
# count   100.000000  100.000000      100.000000        100.000000
# mean     50.500000   38.790000      337.966300         13.940000
# std      29.011492   11.556008      274.506007          8.348253
# min       1.000000   20.000000      101.480000          1.000000
# 25%      25.750000   28.000000      140.387500          6.750000
# 50%      50.500000   39.500000      179.465000         13.000000
# 75%      75.250000   47.250000      533.350000         22.000000
# max     100.000000   59.000000      975.400000         29.000000
#
#        Performance_Rating  Project_Count  No. of Companies Worked
# count           100.00000     100.000000               100.000000
# mean              2.42000       5.200000                 2.630000
# std               1.07478       2.741378                 1.116045
# min               1.00000       1.000000                 1.000000
# ...

# %%
df.shape
# Out:
# (100, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee_ID              100 non-null    int64
#  1   Age                      100 non-null    int64
#  2   Gender                   100 non-null    object
#  3   Department               100 non-null    object
#  4   Job_Role                 100 non-null    object
#  5   Monthly_Income           100 non-null    float64
#  6   Years_at_Company         100 non-null    int64
#  7   Performance_Rating       100 non-null    int64
#  8   Project_Count            100 non-null    int64
#  9   No. of Companies Worked  100 non-null    int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 7.9+ KB

# %%
df.dtypes
# Out:
# Employee_ID                  int64
# Age                          int64
# Gender                      object
# Department                  object
# Job_Role                    object
# Monthly_Income             float64
# Years_at_Company             int64
# Performance_Rating           int64
# Project_Count                int64
# No. of Companies Worked      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Role',
#        'Monthly_Income', 'Years_at_Company', 'Performance_Rating',
#        'Project_Count', 'No. of Companies Worked'],
#       dtype='object')

# %%
# Add Gender Column
val=['Female','Female','Male','Male','Male']
df.loc[:4,'Gender']=val

# %%
df.head()
# Out:
#    Employee_ID  Age  Gender Department   Job_Role  Monthly_Income  \
# 0            1   58  Female         IT    Manager          154.88
# 1            2   48  Female      Sales  Assistant          130.79
# 2            3   34    Male  Marketing  Assistant          137.44
# 3            4   27    Male  Marketing    Manager          680.90
# 4            5   40    Male  Marketing  Executive          102.06
#
#    Years_at_Company  Performance_Rating  Project_Count  \
# 0                15                   4              6
# 1                 6                   1              2
# 2                24                   1              6
# 3                10                   4              9
# 4                29                   1              3
#
#    No. of Companies Worked
# 0                        3
# 1                        2
# 2                        3
# 3                        3
# 4                        3

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender']=le.fit_transform(df['Gender'])

# %%
df
# Out:
#     Employee_ID  Age  Gender Department   Job_Role  Monthly_Income  \
# 0             1   58       0         IT    Manager          154.88
# 1             2   48       0      Sales  Assistant          130.79
# 2             3   34       1  Marketing  Assistant          137.44
# 3             4   27       1  Marketing    Manager          680.90
# 4             5   40       1  Marketing  Executive          102.06
# ..          ...  ...     ...        ...        ...             ...
# 95           96   28       1         HR    Analyst          710.30
# 96           97   27       0         IT  Assistant          507.60
# 97           98   31       0  Marketing  Assistant          599.40
# 98           99   53       0  Marketing  Executive          674.40
# 99          100   52       1         IT    Analyst          174.66
#
#     Years_at_Company  Performance_Rating  Project_Count  \
# 0                 15                   4              6
# ...
